# %%
# 반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt

# 데이터 생성하기
df1 = pd.DataFrame({
    "지역":["서울","부산","대구"],
    "총인구":[1000000,300000,200000]
})
df2 = pd.DataFrame({
    "지역":["서울","부산","인천"],
    "병원수":[150,80,60]
})

# 데이터 전처리를 위해 merge(병합)을 진행한다.
# outer로 병합하면 df1과 df2 합집합이 된다.
merged = pd.merge(df1, df2, on="지역",how="outer")
#merged

# 결측치 처리를 진행한다.
# 결측치는 병원수와, 총인구의 평균으로 정의한다.
merged['총인구'] = merged['총인구'].fillna(merged['총인구'].mean())
merged['병원수'] = merged['병원수'].fillna(merged['병원수'].mean())
merged


# --------------------------------------
# 반드시 한글 깨짐 현상 코드를 삽입한다.
#----------------------------------------
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 차트 배경 + 색상 자동으로 그리드에 빨간색으로 지정
# plt.style.use('ggplot')


# 그래프 크기 지정 : figure(10,6)
plt.figure(figsize=(8,5))

# ------------------------------------
# 세로 막대 그래프 만들기 : plt.bar(x, y)
# x 축 : 지역, 가로축 : 병원수
# 세로막대 넓이 기본 값 : width=0.8
#--------------------------------------
bars = plt.bar(merged["지역"],merged["병원수"],width=0.4, color='skyblue')

# 차트제목, 가로축 제목, 세로축 제목 지정
plt.title("지역별 병원 수")
plt.xlabel("지역")
plt.ylabel("병원수")

# 세로막대 각각의 데이터 레이블 값 출력하는 방법
for bar in bars:
    height = bar.get_height() # 막대 높이 추출하는 함수 예) 대구 : 96
    # bar.get_x() : 막대그래프 넓이의 시작점을 추출
    # bar.get_width() : 막대그래프 넓이전체 추출 
    plt.text(bar.get_x() + bar.get_width()/2, 
            height, f'{int(height)}', ha='center',va='bottom')


# 반드시 저장이 먼저이다.
plt.savefig('hospital_chart.png',dpi=300)

# 그래프 출력
plt.show()

# %%
# 반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt
# seaborn :  matplotlib 기반위에서 차트 이쁘게 꾸미는 도구 
import seaborn as sns

# 데이터 생성하기
df1 = pd.DataFrame({
    "지역":["서울","부산","대구"],
    "총인구":[1000000,300000,200000]
})
df2 = pd.DataFrame({
    "지역":["서울","부산","인천"],
    "병원수":[150,80,60]
})

# 데이터 전처리를 위해 merge(병합)을 진행한다.
# outer로 병합하면 df1과 df2 합집합이 된다.
merged = pd.merge(df1, df2, on="지역",how="outer")
#merged

# 결측치 처리를 진행한다.
# 결측치는 병원수와, 총인구의 평균으로 정의한다.
merged['총인구'] = merged['총인구'].fillna(merged['총인구'].mean())
merged['병원수'] = merged['병원수'].fillna(merged['병원수'].mean())
merged

# seaborn 스타일 지정
sns.set_style('whitegrid') # 배경 스타일 설정, dark : 그리드 없이 어두운 배경 지정
sns.set_palette('pastel') # 색상 스타일 지정, deep :진하게

# --------------------------------------
# 반드시 한글 깨짐 현상 코드를 삽입한다.
#----------------------------------------
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# 차트 배경 + 색상 자동으로 그리드에 빨간색으로 지정
# plt.style.use('ggplot')


# 그래프 크기 지정 : figure(10,6)
plt.figure(figsize=(8,5))

# ------------------------------------
# 세로 막대 그래프 만들기 : plt.bar(x, y)
# x 축 : 지역, 가로축 : 병원수
# 세로막대 넓이 기본 값 : width=0.8
#--------------------------------------
# bars = plt.bar(merged["지역"],merged["병원수"],width=0.4, color='skyblue')
ax = sns.barplot(x='지역', y='병원수', data=merged, width=0.4,palette=['#FF5733','green','blue','orange'])

# 차트제목, 가로축 제목, 세로축 제목 지정
# pad=20 #차트 제목 여백
plt.title("지역별 병원 수", fontsize=18,fontweight='bold',color='darkblue',pad=20)
plt.xlabel("지역",fontsize=14,fontweight='bold',color='purple')
plt.ylabel("병원수",fontsize=14,fontweight='bold',color='orange')

# x축의 눈금의 값 각종 글꼴 지정하기
plt.xticks(fontsize=12,fontweight='bold',color='brown')
plt.yticks(fontsize=12,fontweight='bold',color='black')

# 세로막대 각각의 데이터 레이블 값 출력하는 방법
# for bar in bars:
#     height = bar.get_height() # 막대 높이 추출하는 함수 예) 대구 : 96
#     # bar.get_x() : 막대그래프 넓이의 시작점을 추출
#     # bar.get_width() : 막대그래프 넓이전체 추출 
#     plt.text(bar.get_x() + bar.get_width()/2, 
#             height, f'{int(height)}', ha='center',va='bottom')
for i in range(len(merged['병원수'])):
    v = merged['병원수'][i] # i 번째 병원수 값 출력
    print(f'{i}번째 병원수 : {v}')
    ax.text(
        i,    # x의 위치 (막대위치 : 0,1,2~)
        v,    # y 위치 (막대 높이)
        int(v), # 정수로 표시할 값
        ha='center',
        va='bottom',
        fontsize=12,
        fontweight ='bold',
        color='red'
    )

# 차트 그리드 선모양 지정하는 방법
#plt.grid(linestyle='--') #점선
plt.grid(linestyle=':')  #촘촘한 선
#plt.grid(linestyle='-.') #점+선 혼합


# 반드시 저장이 먼저이다.
# plt.savefig('hospital_chart.png',dpi=300)

# 그래프 요소들의 겹치지 않게 자동으로 간격을 조정해주는 함수
plt.tight_layout()

# 그래프 출력
plt.show()
# Out:
# 0번째 병원수 : 96.66666666666667
# 1번째 병원수 : 80.0
# 2번째 병원수 : 150.0
# 3번째 병원수 : 60.0
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_14720\2417671429.py:52: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='지역', y='병원수', data=merged, width=0.4,palette=['#FF5733','green','blue','orange'])

# %%
# 반드시 pandas는 import하여 사용한다.
import pandas as pd
# matplotlib 매트플롯립도 반드시 import하여 사용한다.
import matplotlib.pyplot as plt

# ---------------------------
# 1. 데이터 생성
# ---------------------------
df1 = pd.DataFrame({
    "지역": ["서울","부산","대구"],
    "총인구": [1000000,300000,200000]
})

df2 = pd.DataFrame({
    "지역": ["서울","부산","인천"],
    "병원수": [150,80,60]
})

# ---------------------------
# 2. 데이터 병합 (outer = 합집합)
# ---------------------------
merged = pd.merge(df1, df2, on="지역", how="outer")

# ---------------------------
# 3. 결측치 처리 (평균값으로 채우기)
# ---------------------------
merged['총인구'] = merged['총인구'].fillna(merged['총인구'].mean())
merged['병원수'] = merged['병원수'].fillna(merged['병원수'].mean())
print(merged)
# ---------------------------
# 4. 한글 깨짐 방지
# ---------------------------
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

fig = plt.figure()
# fig.add_subplot(행, 열, 위치(몇번째 그래인지))
# 1행 1열짜리 그래프에서 1번째 그래프 사용
plots = fig.add_subplot(1,1,1)   # ← 그냥 그래프판 하나 추가

# 막대 그래프
plots.bar(merged["지역"],merged["병원수"],width=0.4, color='skyblue')
plots.set_ylabel('병원수')

# 보조축 생성
plots02 = plots.twinx()

# 꺽은선 그래프
plots02.plot(merged['지역'],merged['병원수'],marker='s', color='red')
plots02.set_ylabel('총인구')

plt.title("지역별 병원수 + 총인구")
plt.show()
# Out:
#    지역        총인구         병원수
# 0  대구   200000.0   96.666667
# 1  부산   300000.0   80.000000
# 2  서울  1000000.0  150.000000
# 3  인천   500000.0   60.000000
