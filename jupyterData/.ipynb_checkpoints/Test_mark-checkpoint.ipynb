# %% [markdown]
# # 1. 데이터 불러오기 (큰 제목)
# ## 1.1 CSV 파일 로드 (소제목)
# --- (가로 구분선: 하이픈 3개)
#
# **텍스트**: 굵게 (중요한 변수나 결과값)
# * 텍스트: 불렛 포인트 (분석 단계 나열)
# 1. 텍스트: 번호 매기기 (전처리 순서)
#
# **분석 결과:** 결측치가 30% 이상인 '나이' 컬럼은 중앙값으로 대체하기로 함.

# %% [markdown]
# # 1
# ## 2
# ### 3
# #### 4
# ##### 5
# ###### 6
